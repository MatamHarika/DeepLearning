# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Dense,LSTM,Embedding,Dropout, add
base_model = VGG16(weights='imagenet')
vgg=Model(inputs=base_model.input, outputs=base_model.layers[-2].output)

# %%
BASE_DIR='Downloads/data'
i=0
IMG_DIR=os.path.join(BASE_DIR, 'Images')
features={}
for img in os.listdir(IMG_DIR):
    if i==100:
        break
    i+=1
    image=load_img(os.path.join(IMG_DIR,img), target_size=(224,224))
    image=preprocess_input(np.expand_dims(img_to_array(image),axis=0))
    features[img.split('.')[0]] = vgg.predict(image,verbose=0)

# %%
mapping={}
i=0
for line in open(os.path.join(BASE_DIR,'captions.txt')):
    if i==100:
        break
    i+=1
    parts=line.strip().split(',')
    if len(parts)<2:
        continue
    img,caption = parts[0].split('.')[0], 'startseq'+' '.join(parts[1:]).lower()+'endseq'
    mapping.setdefault(img,[]).append(caption)

# %%
all_caps = [c for caps in mapping.values() for c in caps]
tok=Tokenizer()
tok.fit_on_texts(all_caps)
vocab,maxlen = len(tok.word_index)+1, max(len(c.split()) for c in all_caps)

# %%
in1 = Input(shape=(4096,))
x1=Dropout(0.4)(in1)
x1=Dense(256,activation='relu')(x1)

in2=Input(shape=(maxlen,))
x2=Embedding(vocab,256,mask_zero=True)(in2)
x2=Dropout(0.4)(x2)
x2=LSTM(256)(x2)
merged=add([x1,x2])
merged=Dense(256,activation='relu')(merged)
output=Dense(vocab,activation='softmax')(merged)

model=Model(inputs=[in1,in2],outputs=output)
model.compile(loss='categorical_crossentropy',optimizer='adam')

dummy_img = np.zeros((1, 4096), dtype='float32')
dummy_seq = np.zeros((1, maxlen), dtype='int32')
model([dummy_img, dummy_seq])
# Out:
# <tf.Tensor: shape=(1, 290), dtype=float32, numpy=
# array([[0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828,
#         0.00344828, 0.00344828, 0.00344828, 0.00344828, 0.00344828]],
#       dtype=float32)>

# %%
def gen(keys):
    while True:
        for k in keys:
            for cap in mapping[k]:
                seq = tok.texts_to_sequences([cap])[0]
                if len(seq) < 2:
                    continue
                for i in range(1, len(seq)):
                    x1 = features[k][0]
                    x2 = pad_sequences([seq[:i]], maxlen=maxlen)[0]
                    y = tf.keras.utils.to_categorical([seq[i]], num_classes=vocab)
                    x1 = np.expand_dims(x1, axis=0)
                    x2 = np.expand_dims(x2, axis=0)
                    yield [x1, x2], y

train = list(mapping.keys())[:10]

model.fit(
    gen(train),
    steps_per_epoch=len(train),
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 8s 48ms/step - loss: 6.1679
# Epoch 2/50
# 10/10 [==============================] - 0s 45ms/step - loss: 7.4426
# Epoch 3/50
# 10/10 [==============================] - 0s 46ms/step - loss: 4.7453
# Epoch 4/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.6851
# Epoch 5/50
# 10/10 [==============================] - 0s 46ms/step - loss: 3.6798
# Epoch 6/50
# 10/10 [==============================] - 0s 44ms/step - loss: 5.4446
# Epoch 7/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.8659
# Epoch 8/50
# 10/10 [==============================] - 0s 51ms/step - loss: 5.8972
# Epoch 9/50
# 10/10 [==============================] - 1s 51ms/step - loss: 6.6289
# Epoch 10/50
# 10/10 [==============================] - 1s 53ms/step - loss: 5.4399
# Epoch 11/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.8057
# Epoch 12/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.0738
# Epoch 13/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.0799
# Epoch 14/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.2182
# Epoch 15/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.7523
# Epoch 16/50
# 10/10 [==============================] - 0s 49ms/step - loss: 5.4168
# Epoch 17/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.8895
# Epoch 18/50
# 10/10 [==============================] - 0s 46ms/step - loss: 3.8975
# Epoch 19/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.5417
# Epoch 20/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.8232
# Epoch 21/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.0518
# Epoch 22/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.2491
# Epoch 23/50
# 10/10 [==============================] - 1s 51ms/step - loss: 4.6208
# Epoch 24/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.8042
# Epoch 25/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.1482
# Epoch 26/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.6621
# Epoch 27/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.9218
# Epoch 28/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.9845
# Epoch 29/50
# 10/10 [==============================] - 0s 46ms/step - loss: 4.8661
# Epoch 30/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.6004
# Epoch 31/50
# 10/10 [==============================] - 1s 64ms/step - loss: 4.5691
# Epoch 32/50
# 10/10 [==============================] - 1s 51ms/step - loss: 5.0149
# Epoch 33/50
# 10/10 [==============================] - 0s 49ms/step - loss: 6.1345
# Epoch 34/50
# 10/10 [==============================] - 0s 47ms/step - loss: 5.5623
# Epoch 35/50
# 10/10 [==============================] - 0s 46ms/step - loss: 4.8939
# Epoch 36/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.4323
# Epoch 37/50
# 10/10 [==============================] - 0s 47ms/step - loss: 4.4711
# Epoch 38/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.6161
# Epoch 39/50
# 10/10 [==============================] - 1s 48ms/step - loss: 4.7594
# Epoch 40/50
# 10/10 [==============================] - 0s 46ms/step - loss: 3.9610
# Epoch 41/50
# 10/10 [==============================] - 0s 48ms/step - loss: 4.5180
# Epoch 42/50
# 10/10 [==============================] - 0s 47ms/step - loss: 5.4844
# Epoch 43/50
# 10/10 [==============================] - 0s 46ms/step - loss: 4.8443
# Epoch 44/50
# 10/10 [==============================] - 0s 45ms/step - loss: 4.7013
# Epoch 45/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.9287
# Epoch 46/50
# 10/10 [==============================] - 0s 48ms/step - loss: 4.5199
# Epoch 47/50
# 10/10 [==============================] - 0s 46ms/step - loss: 4.8218
# Epoch 48/50
# 10/10 [==============================] - 1s 54ms/step - loss: 5.6712
# Epoch 49/50
# 10/10 [==============================] - 0s 45ms/step - loss: 5.1162
# Epoch 50/50
# 10/10 [==============================] - 0s 46ms/step - loss: 5.0003

# %%
def predict_caption(feat):
    text = 'startseq'
    for _ in range(maxlen):
        seq = pad_sequences([tok.texts_to_sequences([text])[0]], maxlen=maxlen)
        yhat = np.argmax(model.predict([feat, seq], verbose=0))
        word = next((w for w, i in tok.word_index.items() if i == yhat), None)
        if word is None or word == 'endseq': break
        text += ' ' + word
    return text.replace('startseq', '').replace('endseq', '').strip()

# === Test ===
img = list(features.keys())[0]
print("Generated caption:", predict_caption(features[img]))
# Out:
# Generated caption: in in in in
